# %%
# !pip install unstructured
# !pip install tiktoken
# !pip install pinecone-client
# !pip install pypdf
# !pip install python-dotenv

# %%
## Import libraries

import openai
import langchain
import pinecone
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
from langchain.llms import OpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
## lets get the pdf
def read_doc(directory):
    file_loader = PyPDFLoader(directory)
    documents = file_loader.load()
    return documents

# %%
doc = read_doc("/Users/santhoshrajesh/Desktop/ML_road_map.pdf")
doc
# Out:
# [Document(page_content='ML Road Map\n1ML Road Map\nWeek 1\nBasics:\nFundamentals \nOPPS\nThreading\nRunning in cloab \nSQL:\nSQL Basics\nTables, DDL, DML, indexes \nQuerying → Joins, GroupBy , Having, Aggregations\nWeek 2\nMathematics for ML ( https://www.youtube.com/watch?\nv=0z6AhrOSrRs )\nData Preprocessing ( https://www.scalablepath.com/data-\nscience/data-preprocessing-phase ) \nData Cleaning ( https://www .youtube.com/watch?v=bDhvCp3_lYw  )\nDimensionality Reduction ( https://www .youtube.com/watch?v=8klqIM9UvAc  )\nPCA\nLDA\nFeature Engineering ( https://www .youtube.com/watch?v=GduT2ZCc26E  )', metadata={'source': '/Users/santhoshrajesh/Desktop/ML_road_map.pdf', 'page': 0}),
# ...

# %%
len(doc)
# Out:
# 6

# %%
## Divide Docs into chunks

def chunk_data(docs, chunk_size = 800, chunk_overlap = 50):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size = chunk_size, chunk_overlap = chunk_overlap)
    doc = text_splitter.split_documents(docs)
    return doc

# %%
documents = chunk_data(doc)
documents
# Out:
# [Document(page_content='ML Road Map\n1ML Road Map\nWeek 1\nBasics:\nFundamentals \nOPPS\nThreading\nRunning in cloab \nSQL:\nSQL Basics\nTables, DDL, DML, indexes \nQuerying → Joins, GroupBy , Having, Aggregations\nWeek 2\nMathematics for ML ( https://www.youtube.com/watch?\nv=0z6AhrOSrRs )\nData Preprocessing ( https://www.scalablepath.com/data-\nscience/data-preprocessing-phase ) \nData Cleaning ( https://www .youtube.com/watch?v=bDhvCp3_lYw  )\nDimensionality Reduction ( https://www .youtube.com/watch?v=8klqIM9UvAc  )\nPCA\nLDA\nFeature Engineering ( https://www .youtube.com/watch?v=GduT2ZCc26E  )', metadata={'source': '/Users/santhoshrajesh/Desktop/ML_road_map.pdf', 'page': 0}),
# ...

# %%
len(documents)
# Out:
# 6

# %%
## Embedding Technique of OpenAI

embeddings = OpenAIEmbeddings(api_key=os.environ['OPENAI_API_KEY'])
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x11f6acd90>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x11eee5eb0>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
vectors = embeddings.embed_query("My name is shandy")
vectors
# Out:
# [-0.014239621248985965,
#  -0.02259572990547708,
#  -0.007252950161813645,
#  -0.021758850951102186,
#  -0.01782805529793375,
#  0.015520299592418905,
#  -0.00529389277885833,
#  0.003066970977523837,
#  -0.010841385607745191,
#  0.0016499827585404682,
#  -0.00301308093196818,
#  0.0018718824530694926,
#  0.0012267884142925975,
#  0.010885764987857491,
#  0.009433907704959237,
#  0.012198143686789939,
#  0.025271205264438167,
#  -0.013846541683669122,
#  0.03076163829161617,
#  -0.007531910123712778,
#  -0.013986021198957433,
#  -0.006511171342614765,
#  0.01101256547853301,
#  0.0047518234984710705,
#  0.008127869449655694,
#  -0.001312378233271194,
#  0.02353404850733438,
#  0.012749723166959302,
#  0.00474548352050342,
#  -0.01908337372949609,
#  -0.0027230263578715986,
#  0.013694381281123,
#  -0.0034077453753616235,
#  -0.024954207297378142,
#  -0.013884581551475024,
#  -0.045952257167072234,
#  -0.004447504090362589,
#  -0.004812053521994378,
#  0.008432188392102923,
# ...

# %%
len(vectors)
# Out:
# 1536

# %%
pc = Pinecone.from_existing_index(
    index_name = "pdfquery",
    embedding = embeddings, 
    namespace = "shandy"
)

# %%
index = pc.from_documents(doc, embeddings, index_name = "pdfquery")

# %%
## Cosine Similarity Retrive Results

def retrieve_query(query, k=2):
    matching_results = index.similarity_search(query, k=k)
    return matching_results

# %%
from langchain.chains.question_answering import load_qa_chain

llm = OpenAI(model_name = "gpt-3.5-turbo-instruct", temperature = 0.5)
chain = load_qa_chain(llm, chain_type="stuff")

# %%
## Search answers from vectorDB

def retrieve_answers(query):
    doc_search = retrieve_query(query)
    print(doc_search)
    response = chain.run(input_documents = doc_search, question = query)
    
    return response

# %%
our_query = "What are the concepts said to learn under cloud computing ?"
answer = retrieve_answers(our_query)
print(answer)
# Out:
# [Document(page_content='ML Road Map\n6TF serve ( https://www .youtube.com/watch?v=1d4BzR_7Nbc&t=295s  )\nProject → \nuse fast API + TF Serve for deploying a any previously developed models\nWeek 7\nCloud Basics:\nWhat is AWS\nWhat is EC2\nWhat is AWS SageMaker\nHow Can we deploy our ML  model in AWS ?\nWhat is Docker\nWhat is Kubernetes', metadata={'page': 5.0, 'source': '/Users/santhoshrajesh/Desktop/ML_road_map.pdf'}), Document(page_content='ML Road Map\n6TF serve ( https://www .youtube.com/watch?v=1d4BzR_7Nbc&t=295s  )\nProject → \nuse fast API + TF Serve for deploying a any previously developed models\nWeek 7\nCloud Basics:\nWhat is AWS\nWhat is EC2\nWhat is AWS SageMaker\nHow Can we deploy our ML  model in AWS ?\nWhat is Docker\nWhat is Kubernetes', metadata={'page': 5.0, 'source': '/Users/santhoshrajesh/Desktop/ML_road_map.pdf'})]
#  Some of the concepts mentioned in the context include AWS, EC2, AWS SageMaker, Docker, and Kubernetes.
